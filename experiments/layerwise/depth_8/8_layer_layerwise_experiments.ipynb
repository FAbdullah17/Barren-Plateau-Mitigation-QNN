# %%
import os
os.environ["TF_USE_LEGACY_KERAS"] = "1"

# Set working directory to project root
os.chdir(os.path.join(os.path.dirname(os.path.abspath('__file__')), '..'))
print(f"Working directory: {os.getcwd()}")
print("\u2705 Legacy Keras enabled for TensorFlow Quantum")
# Out:
# Working directory: /mnt/d/Programs/PF/Hybrid-QNNs
# ✅ Legacy Keras enabled for TensorFlow Quantum

# %% [markdown]
# ### Seed 42

# %%
# !python experiments/run_layerwise.py configs/layerwise_8layer.yaml --seed 42
# Out:
# 2026-02-17 13:23:24.331848: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-17 13:23:24.477578: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-17 13:23:24.673147: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-02-17 13:23:24.830938: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-02-17 13:23:24.831846: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
import json
from pathlib import Path
from IPython.display import Image, display

seed_dir = Path('results/layerwise/depth_8/seed_42')
with open(seed_dir / 'metrics.json') as f:
    m = json.load(f)
print(f"Seed 42 | Accuracy: {m['test_acc']*100:.2f}% | Grad Norm: {m['gradient_stats']['mean_norm']:.6e} | Time: {m['training_time']:.1f}s")
# Display plot (filename may be training_history.png or history.png)
for plot_name in ['training_history.png', 'history.png']:
    if (seed_dir / plot_name).exists():
        display(Image(filename=str(seed_dir / plot_name), width=800))
        break
# Out:
# Seed 42 | Accuracy: 77.00% | Grad Norm: 2.341836e-01 | Time: 2103.4s

# %% [markdown]
# ### Seed 123

# %%
# !python experiments/run_layerwise.py configs/layerwise_8layer.yaml --seed 123
# Out:
# 2026-02-17 13:59:24.154072: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-17 13:59:24.265048: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-17 13:59:24.434862: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-02-17 13:59:24.627748: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-02-17 13:59:24.628446: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
seed_dir = Path('results/layerwise/depth_8/seed_123')
with open(seed_dir / 'metrics.json') as f:
    m = json.load(f)
print(f"Seed 123 | Accuracy: {m['test_acc']*100:.2f}% | Grad Norm: {m['gradient_stats']['mean_norm']:.6e} | Time: {m['training_time']:.1f}s")
for plot_name in ['training_history.png', 'history.png']:
    if (seed_dir / plot_name).exists():
        display(Image(filename=str(seed_dir / plot_name), width=800))
        break
# Out:
# Seed 123 | Accuracy: 73.00% | Grad Norm: 2.402790e-01 | Time: 2052.7s

# %% [markdown]
# ### Seed 456

# %%
# !python experiments/run_layerwise.py configs/layerwise_8layer.yaml --seed 456
# Out:
# 2026-02-17 14:34:29.557498: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-17 14:34:29.672253: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-17 14:34:29.898851: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-02-17 14:34:30.048772: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-02-17 14:34:30.049470: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
seed_dir = Path('results/layerwise/depth_8/seed_456')
with open(seed_dir / 'metrics.json') as f:
    m = json.load(f)
print(f"Seed 456 | Accuracy: {m['test_acc']*100:.2f}% | Grad Norm: {m['gradient_stats']['mean_norm']:.6e} | Time: {m['training_time']:.1f}s")
for plot_name in ['training_history.png', 'history.png']:
    if (seed_dir / plot_name).exists():
        display(Image(filename=str(seed_dir / plot_name), width=800))
        break
# Out:
# Seed 456 | Accuracy: 75.50% | Grad Norm: 2.304937e-01 | Time: 2054.6s

# %% [markdown]
# ### Seed 789

# %%
# !python experiments/run_layerwise.py configs/layerwise_8layer.yaml --seed 789
# Out:
# 2026-02-17 15:09:36.880913: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-17 15:09:36.988114: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-17 15:09:37.131299: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-02-17 15:09:37.242031: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-02-17 15:09:37.242645: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
seed_dir = Path('results/layerwise/depth_8/seed_789')
with open(seed_dir / 'metrics.json') as f:
    m = json.load(f)
print(f"Seed 789 | Accuracy: {m['test_acc']*100:.2f}% | Grad Norm: {m['gradient_stats']['mean_norm']:.6e} | Time: {m['training_time']:.1f}s")
for plot_name in ['training_history.png', 'history.png']:
    if (seed_dir / plot_name).exists():
        display(Image(filename=str(seed_dir / plot_name), width=800))
        break
# Out:
# Seed 789 | Accuracy: 69.50% | Grad Norm: 2.189583e-01 | Time: 2019.0s

# %% [markdown]
# ### Seed 101112

# %%
# !python experiments/run_layerwise.py configs/layerwise_8layer.yaml --seed 101112
# Out:
# 2026-02-17 15:44:07.731321: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-17 15:44:07.841426: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-17 15:44:07.990644: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-02-17 15:44:08.101340: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-02-17 15:44:08.102088: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
seed_dir = Path('results/layerwise/depth_8/seed_101112')
with open(seed_dir / 'metrics.json') as f:
    m = json.load(f)
print(f"Seed 101112 | Accuracy: {m['test_acc']*100:.2f}% | Grad Norm: {m['gradient_stats']['mean_norm']:.6e} | Time: {m['training_time']:.1f}s")
for plot_name in ['training_history.png', 'history.png']:
    if (seed_dir / plot_name).exists():
        display(Image(filename=str(seed_dir / plot_name), width=800))
        break
# Out:
# Seed 101112 | Accuracy: 74.50% | Grad Norm: 1.969630e-01 | Time: 2027.7s

# %% [markdown]
# ## All Results Summary

# %%
import json
import numpy as np
from pathlib import Path

results_dir = Path('results/layerwise/depth_8')
seeds = [42, 123, 456, 789, 101112]

print('=' * 80)
print('8-LAYER LAYERWISE RESULTS SUMMARY')
print('=' * 80)
print(f'{"Seed":<10} {"Test Acc (%)":<14} {"Train Acc (%)":<14} {"Grad Norm":<15} {"BP Detected":<12} {"Time (s)":<10}')
print('-' * 80)

accs = []
for seed in seeds:
    metrics_file = results_dir / f'seed_{seed}' / 'metrics.json'
    if metrics_file.exists():
        with open(metrics_file) as f:
            m = json.load(f)
        acc = m['test_acc'] * 100
        accs.append(acc)
        print(f'{seed:<10} {acc:<14.2f} {m["final_train_acc"]*100:<14.2f} {m["gradient_stats"]["mean_norm"]:<15.6e} {str(m["barren_plateau_detected"]):<12} {m["training_time"]:<10.1f}')
    else:
        print(f'{seed:<10} NOT FOUND')

if accs:
    print('-' * 80)
    print(f'{"MEAN":<10} {np.mean(accs):<14.2f}')
    print(f'{"STD":<10} {np.std(accs):<14.2f}')
print('=' * 80)

# Verify all files saved
print('\nResults files verification:')
for seed in seeds:
    seed_dir = results_dir / f'seed_{seed}'
    metrics_ok = (seed_dir / 'metrics.json').exists()
    plot_ok = any((seed_dir / p).exists() for p in ['training_history.png', 'history.png'])
    status = '\u2705' if (metrics_ok and plot_ok) else '\u274c'
    print(f'  {status} seed_{seed}/  metrics.json={metrics_ok}  plot={plot_ok}')
# Out:
# ...
# 8-LAYER LAYERWISE RESULTS SUMMARY
# ...
# Seed       Test Acc (%)   Train Acc (%)  Grad Norm       BP Detected  Time (s)
# --------------------------------------------------------------------------------
# 42         77.00          72.70          2.341836e-01    False        2103.4
# 123        73.00          73.20          2.402790e-01    False        2052.7
# 456        75.50          72.10          2.304937e-01    False        2054.6
# 789        69.50          75.60          2.189583e-01    False        2019.0
# 101112     74.50          72.50          1.969630e-01    False        2027.7
# --------------------------------------------------------------------------------
# MEAN       73.90
# STD        2.56
# ...
#
# Results files verification:
#   ✅ seed_42/  metrics.json=True  plot=True
#   ✅ seed_123/  metrics.json=True  plot=True
#   ✅ seed_456/  metrics.json=True  plot=True
#   ✅ seed_789/  metrics.json=True  plot=True
#   ✅ seed_101112/  metrics.json=True  plot=True
