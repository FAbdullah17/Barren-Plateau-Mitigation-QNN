# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/FAbdullah17/Hybrid-QNNs.git
# Out:
# Cloning into 'Hybrid-QNNs'...
# remote: Enumerating objects: 374, done.
# remote: Counting objects: 100% (374/374), done.
# remote: Compressing objects: 100% (266/266), done.
# remote: Total 374 (delta 119), reused 306 (delta 75), pack-reused 0 (from 0)
# Receiving objects: 100% (374/374), 15.95 MiB | 22.01 MiB/s, done.
# Resolving deltas: 100% (119/119), done.

# %%
# %cd Hybrid-QNNs
# Out:
# /content/Hybrid-QNNs

# %%
# !ls
# Out:
# configs			  requirements-dev.txt
# DEVELOPER_ASSIGNMENTS.md  requirements.txt
# docs			  Research-Problem-Statement.md
# experiments		  results
# experiment_tracking.csv   setup.py
# LICENSE			  src
# notebooks		  TEAM_TASK_DISTRIBUTION.md
# QUICK_REFERENCE.md	  tests
# README.md		  test_setup.py

# %%
# !git branch
# Out:
# * main

# %%
# !git checkout dev
# Out:
# Branch 'dev' set up to track remote branch 'dev' from 'origin'.
# Switched to a new branch 'dev'

# %%
# !git pull origin dev
# Out:
# From https://github.com/FAbdullah17/Hybrid-QNNs
#  * branch            dev        -> FETCH_HEAD
# Already up to date.

# %%
# !python scripts/check_system.py
# Out:
# ...
# SYSTEM READINESS CHECK
# ...
#
# 📁 DISK SPACE
# ----------------------------------------
# ✓ Available: 71.0 GB / 112.6 GB total
#
# 🐍 PYTHON ENVIRONMENT
# ----------------------------------------
# Python: 3.12.12
# 2026-01-09 10:28:10.707573: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-01-09 10:28:10.731897: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-01-09 10:28:10.731968: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Force TensorFlow to use legacy Keras (TFQ compatibility fix)
import os
os.environ["TF_USE_LEGACY_KERAS"] = "1"

print("✅ Legacy Keras enabled for TensorFlow Quantum")
# Out:
# ✅ Legacy Keras enabled for TensorFlow Quantum

# %%
# !pip install tensorflow==2.16.2 tensorflow-quantum==0.7.5 cirq==1.3.0 pyyaml tqdm matplotlib

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/Hybrid-QNNs
# Out:
# /content/Hybrid-QNNs

# %%
from pathlib import Path

file_path = Path("/content/Hybrid-QNNs/src/data/mnist_loader.py")
text = file_path.read_text()
text = text.replace(
    "tf.keras.datasets.mnist.load_data(path=str(mnist_path))",
    "tf.keras.datasets.mnist.load_data()"
)
file_path.write_text(text)

print("✅ MNIST patch applied")
# Out:
# ✅ MNIST patch applied

# %%
# !python experiments/run_baseline.py configs/baseline_4layer.yaml --seed 42
# Out:
# 2026-01-09 10:46:10.506911: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-01-09 10:46:10.550167: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-01-09 10:46:10.550225: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-01-09 10:46:10.573326: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python experiments/run_baseline.py configs/baseline_4layer.yaml --seed 123
# Out:
# 2026-01-09 11:21:04.859054: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-01-09 11:21:04.883658: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-01-09 11:21:04.883722: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-01-09 11:21:04.900747: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python experiments/run_baseline.py configs/baseline_4layer.yaml --seed  456
# Out:
# 2026-01-09 11:48:36.903787: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-01-09 11:48:36.930280: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-01-09 11:48:36.930335: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-01-09 11:48:36.944716: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python experiments/run_baseline.py configs/baseline_4layer.yaml --seed  789
# Out:
# 2026-01-09 12:14:32.586766: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-01-09 12:14:32.624348: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-01-09 12:14:32.624409: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-01-09 12:14:32.647203: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python experiments/run_baseline.py configs/baseline_4layer.yaml --seed  101112
# Out:
# 2026-01-09 12:42:21.981852: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-01-09 12:42:22.021109: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-01-09 12:42:22.021180: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-01-09 12:42:22.044872: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
import shutil
import os

src = "/content/Hybrid-QNNs/results"
dst = "/content/drive/MyDrive/Hybrid-QNNs-Results"

# Remove old backup if it exists (to avoid error)
if os.path.exists(dst):
    shutil.rmtree(dst)

shutil.copytree(src, dst)
print("✅ Results successfully saved to Google Drive")
# Out:
# ✅ Results successfully saved to Google Drive
